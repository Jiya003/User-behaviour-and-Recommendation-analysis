# %% [markdown]
# <a href="https://colab.research.google.com/github/Jiya003/User-behaviour-and-Recommendation-analysis/blob/main/User_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # USER RECOMMENDATION ANALYSIS

# %% [markdown]
# Name: Divyanshi Maurya
#
# Reg. no. : 12219959
#
# Roll no. :RK22UGA33
#
# Submitted to: Mr.Ved Prakash Chaubey, 63892, UpGrad Campus Instructor.

# %% [markdown]
# ![Lpu logo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Upgrad logo.png](data:image/png;base64,...)

# %% [markdown]
# # Platform Description

# %% [markdown]
#  1. About **Pip**:
#
# **Pip** is the package installer for Python, used to download and install packages and their dependencies. Using pip can automatically install tools like Matplotlib and Seaborn into the Python environment. Developers can quickly install, update, or remove packages with pip, and get all libraries they need for executing data analysis and visualizations.
# **Matplotlib** is a foundational Python library for data visualization, offering extensive tools for creating static, interactive, and animated plots. Its flexibility enables users to generate diverse charts, including line graphs, histograms, and scatter plots. Widely used in Exploratory Data Analysis, Matplotlib helps researchers identify trends, distributions, and relationships within datasets.
#
# ---
#
#
#  2. About **Google Colab**:
#
# **Google Colab** is a cloud-based Jupyter notebook platform good for collaborative data analysis. It comes with pre-installed libraries, provides GPU/TPU support, and integrates well with Python-its workflows for tasks such as Exploratory Data Analysis can be greatly streamlined. Due to its accessibility and shareability, it has become a favorite among researchers and data scientists.
#
# ---
#
#
#  3. About **Python** in EDA:
#
# **Python** is so an incredibly useful language for Exploratory Data Analysis with the resource of libraries such as Pandas, NumPy, Matplotlib, and Seaborn. Extremely effective at manipulations, visualizations, and discovery of insights in data; such a robust ecosystem, all-around, a showstopper when working with tools like pip and platforms like Google Colab is present.

# %% [markdown]
# # Libraries Used:

# %% [markdown]
# 1. **NumPy**:
#    NumPy is a powerful Python library used for numerical computing. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays. NumPy is fundamental for data manipulation and scientific computing.
#
# 2. **Matplotlib**:
#    Matplotlib is a widely used Python library for creating static, animated, and interactive visualizations. It provides a variety of plotting tools such as line charts, bar charts, histograms, and scatter plots. Matplotlib is essential for data analysis and visual exploration.
#
# 3. **mlxtend**:
#    mlxtend (Machine Learning Extensions) is a Python library that offers various tools for machine learning, including algorithms for classification, regression, and clustering. It also includes utilities for feature selection, data preprocessing, and visualization. It’s commonly used for association rule mining and more.
#
# 4. **Apriori**:
#    Apriori is an algorithm used in data mining for discovering association rules between variables in large datasets. The `apriori` function in Python is part of the `mlxtend` library, helping identify frequent item sets in transactional data and enabling market basket analysis and recommendation systems.
#
# 5. **FP-growth**:
#    FP-growth (Frequent Pattern Growth) is a data mining algorithm that efficiently finds frequent item sets in large datasets. Unlike Apriori, which generates candidate item sets, FP-growth uses a compact tree structure (FP-tree) to find item sets without candidate generation, improving performance for large data sets.
#
# 6. **Seaborn**:
#    Seaborn is a Python data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. It simplifies the process of creating complex visualizations like heatmaps, violin plots, and pair plots, making it highly useful for exploratory data analysis.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# I am working on a recommendation system project where I aim to build a user-friendly platform to provide personalized product recommendations. The system utilizes association rule mining techniques, specifically the Apriori and FP-growth algorithms, to uncover relationships between products based on transactional data. My goal is to help users find relevant products by analyzing their behavior and providing suggestions based on frequent item sets.
#
# The project involves collecting data from user interactions, such as purchases and product searches, to generate insights into popular product combinations. I use libraries like NumPy for numerical operations, Matplotlib and Seaborn for data visualization, and mlxtend for implementing the Apriori and FP-growth algorithms. The system will allow users to input a product name and receive recommendations for related items. The core of the system relies on mining association rules from large datasets to understand user preferences and trends.
#
# By using efficient algorithms, I aim to optimize the process of generating recommendations, even with large volumes of data. The overall objective is to enhance user experience by making it easier to discover products that match their interests.

# %% [markdown]
# # Solution

# %% [markdown]
# To solve the problem of building a recommendation system, I followed a structured approach:
#
# 1. **Data Collection and Preprocessing**:
#    I started by collecting transactional data, which included customer purchases and product details. I cleaned and preprocessed the data, handling missing values, encoding categorical variables, and filtering out irrelevant information to ensure the dataset was ready for analysis.
#
# 2. **Frequent Itemset Mining**:
#    I applied the **Apriori** and **FP-growth** algorithms, both available in the `mlxtend` library, to mine frequent itemsets from the transaction data. These algorithms help uncover relationships between products purchased together. While **Apriori** generates frequent itemsets through iterative exploration, I found **FP-growth** to be more efficient for larger datasets because it builds a compact tree structure.
#
# 3. **Generating Association Rules**:
#    After identifying the frequent itemsets, I used them to generate association rules that show relationships between products. I filtered these rules using metrics like **confidence**, **support**, and **lift** to ensure they were meaningful and relevant for recommendations.
#
# 4. **Recommendation Generation**:
#    I built the recommendation system to suggest related products when a user inputs a product name. The system retrieves rules related to that product and ranks them based on the strength of the associations, offering the most relevant recommendations.
#
# 5. **Visualization**:
#    To visualize the patterns and relationships, I used **Matplotlib** and **Seaborn**. These helped me create graphs to understand the distribution of frequent itemsets and the strength of the association rules.
#
# 6. **Optimization**:
#    I fine-tuned the system by adjusting parameters like minimum support and confidence to strike a balance between performance and the quality of recommendations. This optimization ensured the system was efficient even with large datasets.
#
# Through this approach, I successfully built a recommendation system that provides personalized, data-driven product suggestions, enhancing the user experience.

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# # DATA LOADING
#
# I have loaded the dataset, as the dataset is in CSV (Comma separted values) or excel format, to manipulate it well i have change the dataset into dataframes with the help of pandas library.

# %%
import warnings

# Ignoring all warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# Loading the dataset, I have excel file
data = pd.read_excel('Online Retail.xlsx')

# %% [markdown]
# # DATA EXPLORATION
#
# Exploring the data by detecting outliers, removing missing values, checking the formats, by measuring the central tendency or dispersion etc.

# %% [markdown]
# #### Top 5 rows

# %%
print(data.head()) #printing first five rows
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# #### Last 5 rows

# %%
print(data.tail())#last 5 rows
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %% [markdown]
# #### For informative summary

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# None

# %% [markdown]
# #### For describing the dataset (numerical values)

# %%
data.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %% [markdown]
# #### For categorical as well as numerical values

# %%
print(data.describe(include='all'))
# Out:
#         InvoiceNo StockCode                         Description  \
# count    541909.0    541909                              540455
# unique    25900.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       1114.0      2313                                2369
# mean          NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
#
#              Quantity                    InvoiceDate      UnitPrice  \
# count   541909.000000                         541909  541909.000000
# ...

# %% [markdown]
# ## Handling Missing values

# %% [markdown]
# #### Identifying the missing value

# %%
missing_values = data.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Description      1454
# CustomerID     135080
# dtype: int64

# %% [markdown]
# So there are missing values in the dataset. Hence, I need to check the percentage.

# %%
# Calculating the percentage of missing values
missing_values = data.isnull().sum()  # Total missing values
total_values = len(data)  # Total number of rows
missing_percentage = (missing_values / total_values) * 100  # Percentage

# Filtering to show only columns with missing values
missing_percentage = missing_percentage[missing_percentage > 0]

# Displaying the percentage of missing values
print(missing_percentage)
# Out:
# Description     0.268311
# CustomerID     24.926694
# dtype: float64

# %% [markdown]
# Hence the Description : is of 0.27% values are missing so i will drop them.
#
#
# As for customer Id i am making a general-based product recommendation system. I would fill the Customer Id as anoynoms.

# %%
# Dropping rows with missing descriptions
data.dropna(subset=['Description'], inplace=True)

# %% [markdown]
# As customer Id is float we need to change it into string

# %%
# Converting the CustomerID to string type
data['CustomerID'] = data['CustomerID'].astype(str)

# Filling missing CustomerID with 'Anonymous', because
data['CustomerID'] = data['CustomerID'].fillna('Anonymous')

# %% [markdown]
# Verfying the changes

# %%
# Checking for the missing values in CustomerID again, just to be sure
missing_values = data['CustomerID'].isnull().sum()
print(f"Missing CustomerID after filling: {missing_values}")
# Out:
# Missing CustomerID after filling: 0

# %% [markdown]
# # Removing Duplicates

# %%
# Checking for the duplicates in the dataset
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

# Dropping duplicates if any of them exist
if duplicates > 0:
    data.drop_duplicates(inplace=True)
    print(f"Duplicates dropped. New total number of rows: {data.shape[0]}")
else:
    print("No duplicates found.")
# Out:
# Number of duplicate rows: 5268
# Duplicates dropped. New total number of rows: 535187

# %% [markdown]
# Now in Invoice, if it is startting with C: it is cancelled.

# %% [markdown]
# # Removing Cancellations

# %%
# Converting InvoiceNo to string type, for handling NaNs
data['InvoiceNo'] = data['InvoiceNo'].astype(str)

# Filtering out rows where InvoiceNo starts with 'C'
# C refers to cancellation
data = data[~data['InvoiceNo'].str.startswith('C')]

# %% [markdown]
# # Outlier Analysis

# %% [markdown]
# ## Z-Score Method

# %%
from scipy import stats
import numpy as np

# Calculating the Z-scores
z_scores = np.abs(stats.zscore(data[['Quantity', 'UnitPrice']]))
threshold = 3  # Common threshold for identifying outliers

# Identifying outliers, using threshold
outliers_z = (z_scores > threshold)

# Displaying the number of outliers found for each column
num_outliers_z = outliers_z.sum(axis=0)
print(f"Number of outliers detected using Z-score:\n{num_outliers_z}")
# Out:
# Number of outliers detected using Z-score:
# Quantity     525
# UnitPrice    680
# dtype: int64

# %% [markdown]
# ## IQR Method (BoxPlot)

# %%
# Calculating the Q1 (25th percentile) and Q3 (75th percentile)
Q1_quantity = data['Quantity'].quantile(0.25)
Q3_quantity = data['Quantity'].quantile(0.75)
IQR_quantity = Q3_quantity - Q1_quantity

Q1_unit_price = data['UnitPrice'].quantile(0.25)
Q3_unit_price = data['UnitPrice'].quantile(0.75)
IQR_unit_price = Q3_unit_price - Q1_unit_price

# Defining the lower and upper bounds for Quantity
lower_bound_quantity = Q1_quantity - 1.5 * IQR_quantity
upper_bound_quantity = Q3_quantity + 1.5 * IQR_quantity

# Same for the Unit Price
lower_bound_unit_price = Q1_unit_price - 1.5 * IQR_unit_price
upper_bound_unit_price = Q3_unit_price + 1.5 * IQR_unit_price

# Displaying the bounds
print("Quantity Bounds: ", lower_bound_quantity, upper_bound_quantity)
print("Unit Price Bounds: ", lower_bound_unit_price, upper_bound_unit_price)
# Out:
# Quantity Bounds:  -14.0 26.0
# Unit Price Bounds:  -3.0700000000000003 8.45

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the visual style
sns.set(style="whitegrid")

# Creating a figure for boxplots, telling the figure size
plt.figure(figsize=(12, 6))

# Boxplot for Quantity
plt.subplot(1, 2, 1)
sns.boxplot(x=data['Quantity'])
plt.title('Boxplot of Quantity (Including Outliers)')

# Boxplot for Unit Price
plt.subplot(1, 2, 2)
sns.boxplot(x=data['UnitPrice'])
plt.title('Boxplot of Unit Price (Including Outliers)')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Removing Outliers

# %%
# Removing outliers based on the IQR method
data_no_outliers = data[~((data['Quantity'] < lower_bound_quantity) |
                           (data['Quantity'] > upper_bound_quantity) |
                           (data['UnitPrice'] < lower_bound_unit_price) |
                           (data['UnitPrice'] > upper_bound_unit_price))]

# Verifing the shape of the new DataFrame
print(f"Original data shape: {data.shape}")
print(f"Data shape after removing outliers: {data_no_outliers.shape}")
# Out:
# Original data shape: (525936, 8)
# Data shape after removing outliers: (460801, 8)

# %% [markdown]
# ## DataTypes Conversion

# %%
# Checking the data types
print(data_no_outliers.dtypes)
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID             object
# Country                object
# dtype: object

# %% [markdown]
# Everything is correct, no missing values, no outliers, no datatypes conversion error.

# %% [markdown]
# # Feature Engineering
#
# Feature engineering involves creating new features or modifying existing ones to improve the model's performance.

# %% [markdown]
# ### Creating new features

# %%
# Step 1: Calculating the TotalPrice before filtering outliers
data['TotalPrice'] = data['Quantity'] * data['UnitPrice']

# Step 2: Defining the bounds for outlier detection (you should have already calculated lower_bound and upper_bound)
# Example and printing the values for lower and upper bounds
lower_bound = data['TotalPrice'].quantile(0.25) - 1.5 * (data['TotalPrice'].quantile(0.75) - data['TotalPrice'].quantile(0.25))
upper_bound = data['TotalPrice'].quantile(0.75) + 1.5 * (data['TotalPrice'].quantile(0.75) - data['TotalPrice'].quantile(0.25))

# Step 3: Creating a copy of the DataFrame to avoid modifying a slice of the original DataFrame
data_no_outliers = data[(data['TotalPrice'] >= lower_bound) & (data['TotalPrice'] <= upper_bound)].copy()

data_no_outliers.reset_index(drop=True, inplace=True)  # Reset index if needed
data_no_outliers
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 483305    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 483306    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 483307    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 483308    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 483309    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country  TotalPrice
# ...

# %%
data_no_outliers['InvoiceDate_day'] = data_no_outliers['InvoiceDate'].dt.day
data_no_outliers['InvoiceDate_month'] = data_no_outliers['InvoiceDate'].dt.month
data_no_outliers['InvoiceDate_year'] = data_no_outliers['InvoiceDate'].dt.year

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## UNIVARIANT ANALYSIS

# %%
import matplotlib as pyplot
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data_no_outliers['TotalPrice'], bins=30, kde=True)
plt.title('Distribution of Total Price')
plt.xlabel('Total Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud
text = ' '.join(data_no_outliers['Description'].dropna().astype(str))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(x='Country', y='UnitPrice', data=data_no_outliers)
plt.title('Price Distribution by Country (Violin Plot)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Kernel Density Plot

# %%
sns.kdeplot(data_no_outliers['UnitPrice'], shade=True)
plt.title('Price Distribution (KDE)')
plt.show()

# %% [markdown]
# ### Cumulative Distribution Plot

# %%
sorted_data = np.sort(data_no_outliers['UnitPrice'].dropna())
yvals = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
plt.plot(sorted_data, yvals)
plt.title('CDF of Unit Prices')
plt.xlabel('Unit Price')
plt.ylabel('CDF')
plt.show()

# %% [markdown]
# ### Log/ Data Transformation

# %%
data_no_outliers['LogTotalPrice'] = np.log1p(data_no_outliers['TotalPrice'])
sns.histplot(data_no_outliers['LogTotalPrice'], bins=30, kde=True)
plt.title('Log Distribution of Total Price')
plt.xlabel('Log of Total Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### BoxPlot

# %%
sns.boxplot(x=data_no_outliers['TotalPrice'])
plt.title('Box Plot of Total Price')
plt.xlabel('Total Price')
plt.show()

# %%
data_no_outliers.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'TotalPrice', 'InvoiceDate_day',
#        'InvoiceDate_month', 'InvoiceDate_year', 'LogTotalPrice'],
#       dtype='object')

# %%
# Calculating Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data_no_outliers['TotalPrice'].quantile(0.25)
Q3 = data_no_outliers['TotalPrice'].quantile(0.75)

# Calculating IQR
IQR = Q3 - Q1

# Defining the upper and lower bounds for non-outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filtering out the outliers
df = data_no_outliers[(data_no_outliers['TotalPrice'] >= lower_bound) & (data_no_outliers['TotalPrice'] <= upper_bound)]

# %%
sns.boxplot(x=df['TotalPrice'])
plt.title('Box Plot of Total Price')
plt.xlabel('Total Price')
plt.show()

# %%
sns.histplot(df['TotalPrice'], bins=30, kde=True)
plt.title('Distribution of Total Price')
plt.xlabel('Total Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Right Skewed distribution

# %% [markdown]
# ## Checking skewness

# %%
import pandas as pd

# Calculating skewness for relevant columns
skewness = df[['Quantity', 'UnitPrice', 'TotalPrice']].skew()

# Printing the skewness values
print("Skewness of the dataset:")
print(skewness)
# Out:
# Skewness of the dataset:
# Quantity     -35.559071
# UnitPrice      2.796801
# TotalPrice     0.838921
# dtype: float64

# %% [markdown]
# ### Visualizing the skewness

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize the skewed distributions
sns.histplot(df['Quantity'], bins=30)
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

sns.histplot(df['UnitPrice'], bins=30)
plt.title('Distribution of Unit Price')
plt.xlabel('Unit Price')
plt.ylabel('Frequency')
plt.show()

sns.histplot(df['TotalPrice'], bins=30)
plt.title('Distribution of Total Price')
plt.xlabel('Total Price')
plt.ylabel('Frequency')
plt.show()

# %%
print(df['Quantity'].describe())
print(df['Quantity'].value_counts().head(20) ) # Check the most common quantity values
# Out:
# count    477633.000000
# mean          5.896925
# std          38.063944
# min       -9600.000000
# 25%           1.000000
# 50%           3.000000
# 75%           8.000000
# max       12540.000000
# Name: Quantity, dtype: float64
# Quantity
# 1     143073
# 2      80464
# 12     54923
# 6      38274
# 4      36704
# 3      35926
# 10     20695
# 24     18328
# 8      11413
# 5      11061
# 25      4966
# 20      3246
# 16      3155
# 48      2705
# 7       2519
# 36      2229
# 9       1450
# 18       801
# 11       687
# 72       592
# Name: count, dtype: int64

# %%
# Adding a small constant (1) to avoid taking the log of zero
df['LogQuantity'] = np.log(df['Quantity'] + 1)

sns.histplot(df['LogQuantity'], bins=30, kde=True)
plt.title('Log Distribution of Quantity')
plt.xlabel('Log Quantity')
plt.ylabel('Frequency')
plt.show()

# %%
# Pie chart for top 5 customers by total spend
top_customers = data.groupby('CustomerID')['TotalPrice'].sum().nlargest(5)
top_customers.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Customers by Total Spend')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## BIVARIANT ANALYSIS

# %% [markdown]
# ### Q-Q Plot

# %%
import scipy.stats as stats
stats.probplot(data_no_outliers['UnitPrice'].dropna(), dist="norm", plot=plt)
plt.title('Q-Q Plot of Unit Price')
plt.show()

# %% [markdown]
# ### Shaipro-Wilk *Test*

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'TotalPrice', 'InvoiceDate_day',
#        'InvoiceDate_month', 'InvoiceDate_year', 'LogTotalPrice',
#        'LogQuantity'],
#       dtype='object')

# %%
from scipy.stats import shapiro
stat, p = shapiro(data_no_outliers['UnitPrice'].dropna())
print(f"Shapiro-Wilk Test p-value: {p}")
if p > 0.05:
    print("The data seems normally distributed.")
else:
    print("The data does not follow a normal distribution.")
# Out:
# Shapiro-Wilk Test p-value: 5.644383419003971e-177
# The data does not follow a normal distribution.

# %%
from scipy.stats import shapiro
stat, p = shapiro(df['Quantity'].dropna())
print(f"Shapiro-Wilk Test p-value: {p}")
if p > 0.05:
    print("The data seems normally distributed.")
else:
    print("The data does not follow a normal distribution.")
# Out:
# Shapiro-Wilk Test p-value: 5.759035501552797e-223
# The data does not follow a normal distribution.

# %%
from scipy.stats import shapiro
stat, p = shapiro(df['TotalPrice'].dropna())
print(f"Shapiro-Wilk Test p-value: {p}")
if p > 0.05:
    print("The data seems normally distributed.")
else:
    print("The data does not follow a normal distribution.")
# Out:
# Shapiro-Wilk Test p-value: 5.369895635800539e-138
# The data does not follow a normal distribution.

# %% [markdown]
# ### Count Plot

# %%
# Count plot for Country distribution
plt.figure(figsize=(12, 6))
sns.countplot(y='Country', data=df, order=df['Country'].value_counts().index)
plt.title('Distribution of Countries')
plt.xlabel('Count')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ### BoxPlot/Plot- groupBy

# %%
# Top 10 products by total quantity sold
top_products = df.groupby('Description')['Quantity'].sum().nlargest(10)
top_products.plot(kind='bar', color='skyblue')
plt.title('Top 10 Products by Quantity Sold')
plt.xlabel('Product Description')
plt.ylabel('Total Quantity')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Time Series Analysis

# %%
# Converting InvoiceDate to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Time series plot of Total Sales over time
daily_sales = df.groupby(df['InvoiceDate'].dt.date)['TotalPrice'].sum()
daily_sales.plot(figsize=(14, 7), color='orange')
plt.title('Daily Total Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid()
plt.show()

# %% [markdown]
# ## Rolling Average Analysis

# %%
# Calculaing the rolling average (e.g., 7-day rolling average)
rolling_average = daily_sales.rolling(window=7).mean()

# Plotting with rolling average
plt.figure(figsize=(14, 7))
daily_sales.plot(color='orange', label='Daily Sales')
rolling_average.plot(color='blue', label='7-Day Rolling Average')
plt.title('Daily Total Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.legend()
plt.grid()
plt.show()

# %%
# Spearman Correlation
spearman_corr = df[['Quantity', 'UnitPrice']].corr(method='spearman')
print(f"Spearman Correlation:\n{spearman_corr}")

# Pearson Correlation
pearson_corr = df[['Quantity', 'UnitPrice']].corr(method='pearson')
print(f"Pearson Correlation:\n{pearson_corr}")
# Out:
# Spearman Correlation:
#            Quantity  UnitPrice
# Quantity   1.000000  -0.469941
# UnitPrice -0.469941   1.000000
# Pearson Correlation:
#            Quantity  UnitPrice
# Quantity   1.000000  -0.066196
# UnitPrice -0.066196   1.000000

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %%
# Correlation heatmap
plt.figure(figsize=(10, 6))
correlation_matrix = df[['Quantity', 'UnitPrice', 'TotalPrice']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
pairplot_data = df[['TotalPrice', 'Quantity', 'LogTotalPrice']]

# Create a pair plot
sns.pairplot(pairplot_data, diag_kind='kde')
plt.suptitle('Pair Plot of Selected Features', y=1.02)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Convert CustomerID to numerical format if necessary
df['CustomerID'] = df['CustomerID'].astype('category').cat.codes

# Create a 3D scatter plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['TotalPrice'], df['Quantity'], df['CustomerID'], alpha=0.6)

ax.set_xlabel('Total Price')
ax.set_ylabel('Quantity')
ax.set_zlabel('Customer ID')
ax.set_title('3D Scatter Plot of Total Price, Quantity, and Customer ID')

plt.show()

# %% [markdown]
# ### PCA (Principle Component Analysis)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df[['Quantity', 'UnitPrice']])
plt.scatter(pca_result[:, 0], pca_result[:, 1])
plt.title('PCA of Quantities and Prices')
plt.show()

# %% [markdown]
# # FP Growth ANALYSIS

# %%
# Sample 10% of the data from the DataFrame
sampled_df = df.sample(frac=0.1, random_state=42)  # Set random_state for reproducibility

# %% [markdown]
# Creating transactional data

# %%
# Creating a list of transactions
transactions = sampled_df.groupby('CustomerID')['Description'].apply(list).reset_index(name='Products')

# %%
sampled_df.shape
# Out:
# (47763, 14)

# %% [markdown]
# ## Encoding the data

# %%
from mlxtend.preprocessing import TransactionEncoder

# Fitting the transaction encoder
encoder = TransactionEncoder()
onehot = encoder.fit(transactions['Products']).transform(transactions['Products'])
df_onehot = pd.DataFrame(onehot, columns=encoder.columns_)

# %%
df_onehot.shape
# Out:
# (3594, 3365)

# %%
df_onehot.head()
# Out:
#     4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#     DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# 0               False                         False
# 1               False                         False
# 2               False                         False
# 3               False                         False
# 4               False                         False
#
#     I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# ...

# %% [markdown]
# ## Applying

# %%
from mlxtend.frequent_patterns import apriori

# Applying Apriori Algo
frequent_itemsets = apriori(df_onehot, min_support=0.005, use_colnames=True)

# %%
print("Frequent Itemsets:")
print(frequent_itemsets.tail())
# Out:
# Frequent Itemsets:
#       support                                           itemsets
# 639  0.005565  (LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY D...
# 640  0.005008  (LUNCH BAG SUKI DESIGN , LUNCH BAG PINK POLKADOT)
# 641  0.006121  (LUNCH BAG SPACEBOY DESIGN , LUNCH BAG RED RET...
# 642  0.006956  (LUNCH BAG SUKI DESIGN , LUNCH BAG SPACEBOY DE...
# 643  0.006400   (LUNCH BAG WOODLAND, LUNCH BAG SPACEBOY DESIGN )
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(frequent_itemsets.head())
print(frequent_itemsets.info())
# Out:
#     support                               itemsets
# 0  0.006400     ( SET 2 TEA TOWELS I LOVE LONDON )
# 1  0.005287               (10 COLOUR SPACEBOY PEN)
# 2  0.005565      (12 MESSAGE CARDS WITH ENVELOPES)
# 3  0.008625        (12 PENCIL SMALL TUBE WOODLAND)
# 4  0.007791  (12 PENCILS SMALL TUBE RED RETROSPOT)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644 entries, 0 to 643
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   support   644 non-null    float64
#  1   itemsets  644 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 10.2+ KB
# None
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# ...

# %%
import mlxtend
print(mlxtend.__version__)
# Out:
# 0.23.2
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(frequent_itemsets.head())
print(frequent_itemsets.dtypes)
# Out:
#     support                               itemsets
# 0  0.006400     ( SET 2 TEA TOWELS I LOVE LONDON )
# 1  0.005287               (10 COLOUR SPACEBOY PEN)
# 2  0.005565      (12 MESSAGE CARDS WITH ENVELOPES)
# 3  0.008625        (12 PENCIL SMALL TUBE WOODLAND)
# 4  0.007791  (12 PENCILS SMALL TUBE RED RETROSPOT)
# support     float64
# itemsets     object
# dtype: object
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def clean_itemsets(item):
    # If it's a frozenset, flatten its contents
    if isinstance(item, frozenset):
        return frozenset(e for sub_item in item for e in (sub_item if isinstance(sub_item, frozenset) else [sub_item]))
    return frozenset([item])  # Wrap single elements into a frozenset

# Apply the cleaning function
frequent_itemsets['itemsets'] = frequent_itemsets['itemsets'].apply(clean_itemsets)

# Verify the cleaned DataFrame
print(frequent_itemsets.head())
# Out:
#     support                               itemsets
# 0  0.006400     ( SET 2 TEA TOWELS I LOVE LONDON )
# 1  0.005287               (10 COLOUR SPACEBOY PEN)
# 2  0.005565      (12 MESSAGE CARDS WITH ENVELOPES)
# 3  0.008625        (12 PENCIL SMALL TUBE WOODLAND)
# 4  0.007791  (12 PENCILS SMALL TUBE RED RETROSPOT)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
frequent_itemsets['itemsets'] = frequent_itemsets['itemsets'].apply(lambda x: frozenset(x) if isinstance(x, (tuple, list)) else x)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(frequent_itemsets)
# Out:
#       support                                           itemsets
# 0    0.006400                 ( SET 2 TEA TOWELS I LOVE LONDON )
# 1    0.005287                           (10 COLOUR SPACEBOY PEN)
# 2    0.005565                  (12 MESSAGE CARDS WITH ENVELOPES)
# 3    0.008625                    (12 PENCIL SMALL TUBE WOODLAND)
# 4    0.007791              (12 PENCILS SMALL TUBE RED RETROSPOT)
# ..        ...                                                ...
# 639  0.005565  (LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY D...
# 640  0.005008  (LUNCH BAG SUKI DESIGN , LUNCH BAG PINK POLKADOT)
# 641  0.006121  (LUNCH BAG SPACEBOY DESIGN , LUNCH BAG RED RET...
# 642  0.006956  (LUNCH BAG SUKI DESIGN , LUNCH BAG SPACEBOY DE...
# 643  0.006400   (LUNCH BAG WOODLAND, LUNCH BAG SPACEBOY DESIGN )
#
# [644 rows x 2 columns]
# ...

# %%
print(frequent_itemsets.dtypes)
# Out:
# support     float64
# itemsets     object
# dtype: object
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
import time
start_time=time.time()
# Apply FP-Growth Algorithm to find frequent itemsets
frequent_itemsets = fpgrowth(df_onehot, min_support=0.005, use_colnames=True)

# Print the frequent itemsets
print("Frequent Itemsets Using FP-Growth Algorithm:\n", frequent_itemsets)

# **Determine num_itemsets - for example, using the length of the frequent itemsets:**
num_itemsets = len(frequent_itemsets)

# Generate association rules from the frequent itemsets, including num_itemsets
rules = association_rules(frequent_itemsets, num_itemsets, metric="lift", min_threshold=1.0)

# Display the rules
print("\nGenerated Association Rules from FP-Growth:\n", rules)
end_time = time.time()
print(f"Time taken for FP: {end_time - start_time} seconds")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Frequent Itemsets Using FP-Growth Algorithm:
#        support                                           itemsets
# 0    0.022259                        (ALARM CLOCK BAKELIKE RED )
# 1    0.011686               (VINTAGE HEADS AND TAILS CARD GAME )
# 2    0.006678                              (TEA TIME OVEN GLOVE)
# 3    0.013077                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 4    0.012243                      (PACK OF 72 SKULL CAKE CASES)
# ..        ...                                                ...
# 639  0.005565  (LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY D...
# ...

# %%
# Displaying the top rules
rules.sort_values(by='lift', ascending=False).head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                             antecedents                          consequents  \
# 30     (JUMBO  BAG BAROQUE BLACK WHITE)  (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 31  (JUMBO SHOPPER VINTAGE RED PAISLEY)     (JUMBO  BAG BAROQUE BLACK WHITE)
# 13                (LUNCH BAG CARS BLUE)                 (LUNCH BAG WOODLAND)
# 12                 (LUNCH BAG WOODLAND)                (LUNCH BAG CARS BLUE)
# 21                (LUNCH BAG CARS BLUE)             (LUNCH BAG SUKI DESIGN )
# 20             (LUNCH BAG SUKI DESIGN )                (LUNCH BAG CARS BLUE)
# 23                (LUNCH BAG CARS BLUE)            (LUNCH BAG PINK POLKADOT)
# ...

# %%
sampled_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        InvoiceNo StockCode                        Description  Quantity  \
# 408378    575851     23296     SET OF 6 TEA TIME BAKING CASES         1
# 200223    556578     22333  RETROSPOT PARTY BAG + STICKER SET         8
# 181846    554663     22456    NATURAL SLATE CHALKBOARD LARGE          1
# 203649    556970     23202             JUMBO BAG VINTAGE LEAF        10
# 188439    555397     22227   HANGING HEART MIRROR DECORATION          4
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 408378 2011-11-11 12:13:00       1.25        1639  United Kingdom        1.25
# ...

# %%
print("Rules DataFrame Structure:")
print(rules.head())  # for showing the first few rows of the rules DataFrame
print("Columns in Rules DataFrame:")
print(rules.columns)  # To List the columns present in the DataFrame
# Out:
# Rules DataFrame Structure:
#                     antecedents                   consequents  \
# 0  (LUNCH BAG SPACEBOY DESIGN )     (LUNCH BAG RED RETROSPOT)
# 1     (LUNCH BAG RED RETROSPOT)  (LUNCH BAG SPACEBOY DESIGN )
# 2      (LUNCH BAG SUKI DESIGN )     (JUMBO BAG RED RETROSPOT)
# 3     (JUMBO BAG RED RETROSPOT)      (LUNCH BAG SUKI DESIGN )
# 4      (LUNCH BAG SUKI DESIGN )  (LUNCH BAG SPACEBOY DESIGN )
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.028381            0.027546  0.006121    0.215686   7.830065
# 1            0.027546            0.028381  0.006121    0.222222   7.830065
# 2            0.023372            0.028102  0.005008    0.214286   7.625177
# 3            0.028102            0.023372  0.005008    0.178218   7.625177
# 4            0.023372            0.028381  0.006956    0.297619  10.486695
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# ...

# %%
def get_recommendations(product_name):
    # Filtering out the rules for the given product name
    product_rules = rules[rules['antecedents'].apply(lambda x: product_name in x)]

    # For Extracting the top 5 recommendations based on lift
    recommendations = product_rules[['consequents', 'support', 'confidence', 'lift']].nlargest(5, 'lift')

    return recommendations

product_to_recommend = 'LUNCH BAG RED RETROSPOT'
recommendations = get_recommendations(product_to_recommend)
print(recommendations)
# Out:
#                      consequents   support  confidence      lift
# 27     (LUNCH BAG PINK POLKADOT)  0.005008    0.181818  9.470356
# 1   (LUNCH BAG SPACEBOY DESIGN )  0.006121    0.222222  7.830065
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f"Time taken for FP: {end_time - start_time} seconds")
# Out:
# Time taken for FP: 1.5538816452026367 seconds
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Apriori analysis

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import time

# Starting the timer
start_time = time.time()

# Handling NaN values by filling the missing values (example: fill with 0)
sampled_df_cleaned = sampled_df.fillna(0)
sampled_df_cleaned = sampled_df_cleaned.sample(frac=0.1, random_state=42)

# Converting the relevant columns to binary (1 if purchased, 0 if not)

unique_products = sampled_df_cleaned['StockCode'].unique()


transaction_matrix = pd.DataFrame(0, index=sampled_df_cleaned.index, columns=unique_products)


for index, row in sampled_df_cleaned.iterrows():
    transaction_matrix.loc[index, row['StockCode']] = 1



frequent_itemsets_1 = apriori(transaction_matrix, min_support=0.001, use_colnames=True)
num_itemsets=len(frequent_itemsets_1)

if frequent_itemsets_1.empty:
    print("No frequent itemsets found. Consider lowering the min_support value.")
else:
    # Generating the association rules from frequent itemsets
    rules_1 = association_rules(frequent_itemsets_1,num_itemsets, metric="confidence", min_threshold=0.005)

    # Stopping the timer
    end_time = time.time()

    # Calculating the total time taken
    execution_time = end_time - start_time

    # Displaying the results and time taken
    print("Frequent Itemsets:\n", frequent_itemsets_1)
    print("\nAssociation Rules:\n", rules_1)
    print(f"\nTime taken for Apriori and rule generation: {execution_time:.4f} seconds")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Frequent Itemsets:
#        support  itemsets
# 0    0.002094   (21034)
# 1    0.002303   (22865)
# 2    0.001675  (85099F)
# 3    0.001256   (23295)
# 4    0.001256   (23173)
# ..        ...       ...
# 262  0.001047   (22333)
# 263  0.001047   (22755)
# 264  0.001047   (22079)
# 265  0.001047   (21481)
# 266  0.001047   (21154)
#
# ...

# %% [markdown]
# # **Analysis:**
#
# In my experiment, I compared the execution times of **FP-Growth** and **Apriori** algorithms on different portions of the dataset. The results were as follows:
#
# 1. **FP-Growth (0.1% of data, 1.55 sec)**:
#    - FP-Growth was applied to 0.1% of the dataset and completed in 1.55 seconds. This shows that FP-Growth can efficiently mine frequent itemsets even when dealing with a larger sample of the data. The algorithm's ability to work with compressed data (using the FP-tree structure) allows it to perform faster, even as the dataset size increases.
#
# 2. **Apriori (0.01% of data, 5.22 sec)**:
#    - Apriori was tested on a much smaller sample (0.01% of the data), yet it still took 5.22 seconds to complete. This indicates that **Apriori's performance degrades significantly**, even when a smaller portion of the data is used. The reason for this slower performance is that Apriori generates candidate itemsets in each iteration, which becomes computationally expensive as the dataset grows.
#
# 3. **Impact of Sampling**:
#    - The fact that I used different percentages of data for each algorithm (0.1% for FP-Growth and 0.01% for Apriori) also highlights the difference in how each algorithm scales with data size. FP-Growth was able to process a larger sample in less time, demonstrating its better scalability and efficiency compared to Apriori, which struggled even with a smaller portion of the dataset.
#
# ---
#
# # **Conclusion:**
#
# From the results, I concluded that **FP-Growth** outperforms **Apriori** significantly in terms of both execution time and scalability, even when using larger portions of the data.
#
# - **FP-Growth** demonstrated faster performance (1.55 seconds for 0.1% of the data) due to its efficient use of an FP-tree structure, which avoids generating candidate itemsets and reduces memory usage. This makes FP-Growth the better choice for handling larger datasets.
#
# - **Apriori**, despite being tested on a smaller sample (0.01%), took considerably longer (5.22 seconds). This suggests that Apriori’s performance could become even more inefficient as the data size increases, primarily because of the costly candidate generation process.
#
# In conclusion, **FP-Growth** is the preferred algorithm when working with larger datasets or when execution time is a critical factor. **Apriori**, while still useful for smaller datasets, becomes impractical for larger-scale data due to its slower execution time.

# %% [markdown]
# ![Untitled.jpg](data:image/jpeg;base64,...)
